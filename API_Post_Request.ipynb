# %%
import requests

cookies = {
    '_ga': 'GA1.2.1537868110.1668155723',
    '_cc_id': '540d104b53584e412d3a9fe0b15deb21',
    '__gads': 'ID=2b6883f4b3f927ab-22452c9024d70009:T=1668155726:S=ALNI_MYfdkIlKsCxbkTLO-7q2y5YZRDxig',
    'ASP.NET_SessionId': 'eti5gvurebq4cpk3xm1x4hnc',
    'cto_bundle': '9HRH4l8wN0REVTVtM3NuY0dpNiUyQkdaMGZqdG5DNkltYVE0YUZObmRFUHlIamxjQm9ZdGhWOWpQWmJuekljOUYyR1E4bkRkYXV1WFRISkM0WXZPbUpzeEYwYVdOeThGJTJCYUh1S1lHQURLb3IxbmJpMUNqRjhEaUdYdTZRUjQzaDNvclU0NGtrb1ZFQTNwcGJxJTJCUFJiYyUyQnlxM0ZMNE4yc2E2N0F3blJJOSUyRnFCQlF3RGdZJTNE',
    '__auc': '1b21425618485d74d81dd0d44c1',
    '_gid': 'GA1.2.24982156.1670155628',
    '__gpi': 'UID=00000b1e447fb11c:T=1668155726:RT=1670155627:S=ALNI_Mb48kMxn2qgs2LwnY0_IUmlpYZ5vg',
}

headers = {
    'authority': 'natega.dostor.org',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'accept-language': 'en-US,en;q=0.9',
    'cache-control': 'max-age=0',
    # 'cookie': '_ga=GA1.2.1537868110.1668155723; _cc_id=540d104b53584e412d3a9fe0b15deb21; __gads=ID=2b6883f4b3f927ab-22452c9024d70009:T=1668155726:S=ALNI_MYfdkIlKsCxbkTLO-7q2y5YZRDxig; ASP.NET_SessionId=eti5gvurebq4cpk3xm1x4hnc; cto_bundle=9HRH4l8wN0REVTVtM3NuY0dpNiUyQkdaMGZqdG5DNkltYVE0YUZObmRFUHlIamxjQm9ZdGhWOWpQWmJuekljOUYyR1E4bkRkYXV1WFRISkM0WXZPbUpzeEYwYVdOeThGJTJCYUh1S1lHQURLb3IxbmJpMUNqRjhEaUdYdTZRUjQzaDNvclU0NGtrb1ZFQTNwcGJxJTJCUFJiYyUyQnlxM0ZMNE4yc2E2N0F3blJJOSUyRnFCQlF3RGdZJTNE; __auc=1b21425618485d74d81dd0d44c1; _gid=GA1.2.24982156.1670155628; __gpi=UID=00000b1e447fb11c:T=1668155726:RT=1670155627:S=ALNI_Mb48kMxn2qgs2LwnY0_IUmlpYZ5vg',
    'origin': 'https://natega.dostor.org',
    'referer': 'https://natega.dostor.org/',
    'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
}

data = {
    'seating_no': '222222',
}

response = requests.post('https://natega.dostor.org/Home/Result', cookies=cookies, headers=headers, data=data)

# %%
response.text
# Out:
# '\n<head>\n<title>نتيجة الثانوية العامة - جريدة الدستور</title>\n<meta http-equiv="Content-Type" content="charset=utf-8" />\n<meta content=\'width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0\' name=\'viewport\' />\n<link href="/Images/Domain/natega.dostor.favicon.ico" rel="shortcut icon" type="image/x-icon" />\n<meta name="description" content="نتيجة الثانوية العامة 2022 برقم الجلوس على جريدة الدستور" />\n<meta name="keywords" content="نتيجة الثانوية العامة,الثانوية العامة 2022,نتيجة الثانوية العامة برقم الجلوس" />\n<link rel="canonical" href=http://natega.dostor.org />\n<meta property="og:locale" content="ar_AR" />\n<meta property="og:type" content="website" />\n<meta property="og:title" content="نتيجة الثانوية العامة 2022 برقم الجلوس على جريدة الدستور" />\n<meta property="og:description" content="نتيجة الثانوية العامة 2022" />\n<meta property="og:url" content=http://natega.dostor.org />\n<meta property="og:site_name" content="جريدة الدستور" />\n<meta propert
# ...

# %%
import requests


headers = {
    
    'referer': 'https://natega.dostor.org/',
    
}

data = {
    'seating_no': '222222',
}

response = requests.post('https://natega.dostor.org/Home/Result', cookies=cookies, headers=headers, data=data)

# %%
response.text
# Out:
# '\n<head>\n<title>نتيجة الثانوية العامة - جريدة الدستور</title>\n<meta http-equiv="Content-Type" content="charset=utf-8" />\n<meta content=\'width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0\' name=\'viewport\' />\n<link href="/Images/Domain/natega.dostor.favicon.ico" rel="shortcut icon" type="image/x-icon" />\n<meta name="description" content="نتيجة الثانوية العامة 2022 برقم الجلوس على جريدة الدستور" />\n<meta name="keywords" content="نتيجة الثانوية العامة,الثانوية العامة 2022,نتيجة الثانوية العامة برقم الجلوس" />\n<link rel="canonical" href=http://natega.dostor.org />\n<meta property="og:locale" content="ar_AR" />\n<meta property="og:type" content="website" />\n<meta property="og:title" content="نتيجة الثانوية العامة 2022 برقم الجلوس على جريدة الدستور" />\n<meta property="og:description" content="نتيجة الثانوية العامة 2022" />\n<meta property="og:url" content=http://natega.dostor.org />\n<meta property="og:site_name" content="جريدة الدستور" />\n<meta propert
# ...

# %% [markdown]
# To organize the code use Beauitful soup library

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(response.content)

# %%
soup
# Out:
# <html><head>
# <title>نتيجة الثانوية العامة - جريدة الدستور</title>
# <meta content="charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
# <link href="/Images/Domain/natega.dostor.favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <meta content="نتيجة الثانوية العامة 2022 برقم الجلوس على جريدة الدستور" name="description"/>
# <meta content="نتيجة الثانوية العامة,الثانوية العامة 2022,نتيجة الثانوية العامة برقم الجلوس" name="keywords"/>
# <link href="http://natega.dostor.org" rel="canonical"/>
# <meta content="ar_AR" property="og:locale"/>
# <meta content="website" property="og:type"/>
# <meta content="نتيجة الثانوية العامة 2022 برقم الجلوس على جريدة الدستور" property="og:title"/>
# <meta content="نتيجة الثانوية العامة 2022" property="og:description"/>
# <meta content="http://natega.dostor.org" property="og:url"/>
# <meta content="جريدة الدستور" property="og:site_name"/>
# ...
