# %%
import requests

cookies = {
    '__gads': 'ID=01cf563a1cdc95c3-224ab8a431d600d2:T=1666336294:RT=1666336294:S=ALNI_MaIdULLVzRLqtQnmyFAyR6szt44gA',
    '_gid': 'GA1.2.568062931.1670157371',
    '__gpi': 'UID=00000b13cba021b0:T=1666336294:RT=1670157370:S=ALNI_MYP3pL6BywOhExd5JPfKW8bEyvcZw',
    'XSRF-TOKEN': '%3D',
    'laravel_session': '%3D',
    '_gat_gtag_UA_67885755_1': '1',
    '_ga_98RM5XLQD9': 'GS1.1.1670157370.13.1.1670157935.0.0.0',
    '_ga': 'GA1.2.1392058403.1666336293',
}

headers = {
    'authority': 'shbabbek.com',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'accept-language': 'en-US,en;q=0.9',
    # 'cookie': '__gads=ID=01cf563a1cdc95c3-224ab8a431d600d2:T=1666336294:RT=1666336294:S=ALNI_MaIdULLVzRLqtQnmyFAyR6szt44gA; _gid=GA1.2.568062931.1670157371; __gpi=UID=00000b13cba021b0:T=1666336294:RT=1670157370:S=ALNI_MYP3pL6BywOhExd5JPfKW8bEyvcZw; XSRF-TOKEN=%3D; laravel_session=%3D; _gat_gtag_UA_67885755_1=1; _ga_98RM5XLQD9=GS1.1.1670157370.13.1.1670157935.0.0.0; _ga=GA1.2.1392058403.1666336293',
    'referer': 'https://shbabbek.com/natega',
    'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
}

response = requests.get('https://shbabbek.com/natega/222222', cookies=cookies, headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
import requests

response = requests.get('https://shbabbek.com/natega/222222', cookies=cookies, headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '<!DOCTYPE html> <html lang="en"> <head> <title>Ù\x86ØªÙ\x8aØ¬Ø© Ù\x88ØªÙ\x86Ø³Ù\x8aÙ\x82 Ø§Ù\x84Ø«Ø§Ù\x86Ù\x88Ù\x8aØ© Ø§Ù\x84Ø¹Ø§Ù\x85Ø© Ø§Ù\x84Ø¯Ù\x88Ø± Ø§Ù\x84Ø«Ø§Ù\x86Ù\x89 2022 Ø¨Ø§Ù\x84Ø§Ø³Ù\x85 Ù\x88Ø§Ù\x84Ù\x85Ø¯Ø±Ø³Ø© Ù\x88ØªØ±ØªÙ\x8aØ¨ Ø§Ù\x84Ø¬Ù\x85Ù\x87Ù\x88Ø±Ù\x8aØ© Ù\x88ØªÙ\x88Ù\x82Ø¹Ø§Øª Ø§Ù\x84ØªÙ\x86Ø³Ù\x8aÙ\x82 - Ù\x85Ù\x88Ù\x82Ø¹ Ø´Ø¨Ø§Ø¨Ù\x8aÙ\x83</title> <meta property="og:title" content=\'Ù\x86ØªÙ\x8aØ¬Ø© Ø§Ù\x84Ø«Ø§Ù\x86Ù\x88Ù\x8aØ© Ø§Ù\x84Ø¹Ø§Ù\x85Ø© 2022 Ø¨Ø§Ù\x84Ø§Ø³Ù\x85 Ù\x88Ø§Ù\x84Ù\x85Ø¯Ø±Ø³Ø© Ù\x88ØªØ±ØªÙ\x8aØ¨ Ø§Ù\x84Ø¬Ù\x85Ù\x87Ù\x88Ø±Ù\x8aØ© - Ù\x85Ù\x88Ù\x82Ø¹ Ø´Ø¨Ø§Ø¨Ù\x8aÙ\x83\' /> <meta property="og:description" content=\'Ù\x84Ø£Ù\x88Ù\x84 Ù\x85Ø±Ù\x87 Ø¹Ù\x84Ù\x89 Ù\x85Ù\x88Ù\x82Ø¹ Ø´Ø¨Ø§Ø¨Ù\x8aÙ\x83 Ù\x86ØªÙ\x8aØ¬Ø© Ø§Ù\x84Ø«Ø§Ù\x86Ù\x88Ù\x8aØ© Ø§Ù\x84Ø¹Ø§Ù\x85Ø© 2022\' /> <meta charset="UTF-8"> <meta property="og:type" content="article" /> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=device-width, 
# ...

# %% [markdown]
# To organize the output using Beautifulsoup

# %%
from bs4 import BeautifulSoup

# %%
soup= BeautifulSoup(response.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...
