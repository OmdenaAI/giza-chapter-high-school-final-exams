# %% [markdown]
# ![api and webscraping.jpg](data:image/jpeg;base64,...)

# %%
import pandas as pd
import pandas as pd
import requests 
import csv 
from itertools import zip_longest
from bs4 import BeautifulSoup
import asyncio
import aiohttp
import time
import gc
import attr
from tqdm import tqdm

# %%
my_list=[]
for seats in range (900000,900010):
  response=requests.get(f'https://shbabbek.com/natega/{seats}')
  try:

   if response.status_code ==200:
     my_list.append(response)     
    
  except:
    break

# %% [markdown]
# Test Code

# %%
my_list
# Out:
# [<Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>]

# %%
my_list[0].text
# Out:
# '<!DOCTYPE html> <html lang="en"> <head> <title>نتيجة وتنسيق الثانوية العامة الدور الثانى 2022 بالاسم والمدرسة وترتيب الجمهورية وتوقعات التنسيق - موقع شبابيك</title> <meta property="og:title" content=\'نتيجة الثانوية العامة 2022 بالاسم والمدرسة وترتيب الجمهورية - موقع شبابيك\' /> <meta property="og:description" content=\'لأول مره على موقع شبابيك نتيجة الثانوية العامة 2022\' /> <meta charset="UTF-8"> <meta property="og:type" content="article" /> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"> <link rel="preload" href="//fonts.gstatic.com/ea/notonaskharabicui/v1/NotoNaskhArabicUI-Regular.woff2" crossorigin="anonymous" as="font" type="font/woff2"> <link rel="preload" href="https://fonts.gstatic.com/s/notokufiarabic/v8/CSRk4ydQnPyaDxEXLFF6LZVLKrodrOYFFg.woff2" crossorigin="anonymous" as="font" type="font/woff2"> <meta name="google-site-verification" content="yCpKJTILfbonDIdXsgFFZskmEGC_5x_6mpCCYcrHqsY" /> <meta name="theme-color" content="#ffffff"> <link rel="manifest" href="/manifest.json"> <link rel="preload" type="font/woff2" as="font" href="https://fonts.gstatic.com/s/notokufiarabic/v8/CSRk4ydQnPyaDxEXLFF6LZVLKrodrOYFFg.woff2" crossorigin="anonymous"> <link rel="preload" type="font/woff2" as="font" href="//fonts.gstatic.com/ea/notonaskharabicui/v1/NotoNaskhArabicUI-Regular.woff2" crossorigin="anonymous"> <script async src="https://www.googletagmanager.com/gtag/js?id=UA-67885755-1"></script> <script> window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag(\'js\', new Date()); gtag(\'config\', \'UA-67885755-1\'); </script> <script async src="https://www.googletagmanager.com/gtag/js?id=G-98RM5XLQD9"></script> <script> window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag(\'js\', new Date()); gtag(\'config\', \'G-98RM5XLQD9\'); </script> <script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js" crossorigin="anonymous"></script> <ins class="adsbygoogle" style="display:block" data-ad-client="ca-pub-4021893257422147" data-ad-format="auto" data-ad-channel="4776241739" data-full-width-responsive="true"></ins> <script> (adsbygoogle = window.adsbygoogle || []).push({}); </script> <link rel="preload" href="https://shbabbek.com/assets/css/sty_all_min.css" as="style" /> <link rel="stylesheet" href="https://shbabbek.com/assets/css/sty_all_min.css"> <link rel="stylesheet" href="https://cdn.datatables.net/1.12.1/css/jquery.dataTables.min.css"> <style> html{font-family:Greta,BlinkMacSystemFont,"Segoe UI",Roboto,"Helvetica Neue",Noto,sans-serif;font-size:16px;font-weight:400;line-height:1.5;-webkit-text-size-adjust:100%;background:#fff;color:#666}body{margin:0}a{-webkit-text-decoration-skip:objects}a:active,a:hover{outline:0}a{color:#1e87f0;text-decoration:none;cursor:pointer}a:hover{color:#0f6ecd;text-decoration:underline}strong{font-weight:bolder}img{vertical-align:middle}.nav-search-button svg{width:50%;margin:25% 5px 5px}img{max-width:100%;box-sizing:border-box}p,ul{margin:0}*+p,*+ul{margin-top:20px}h1,h2,h3,h4{margin:0 0 10px;font-family:-apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,"Helvetica Neue",Noto,sans-serif;font-weight:400;color:#333;text-transform:none}*+h2{margin-top:0}h1{font-size:2.23125rem;line-height:1.2}h2{font-size:1.7rem;line-height:1.3}h3{font-size:1.5rem;line-height:1.4}h4{font-size:1.25rem;line-height:1.4}@media (min-width:960px){h1{font-size:2.625rem}h2{font-size:2rem}}ul{padding-left:30px}ul>li>ul{margin:0}::-moz-selection{background:#39f;color:#fff;text-shadow:none}::selection{background:#39f;color:#fff;text-shadow:none}a,button,input{touch-action:manipulation}@media print{*,::after,::before{background:0 0!important;color:#000!important;box-shadow:none!important;text-shadow:none!important}a,a:visited{text-decoration:underline}img{page-break-inside:avoid;max-width:100%!important}h2,h3,p{orphans:3;widows:3}h2,h3{page-break-aft ...

# %%
my_list[9].text
# Out:
# '<!DOCTYPE html> <html lang="en"> <head> <title>نتيجة وتنسيق الثانوية العامة الدور الثانى 2022 بالاسم والمدرسة وترتيب الجمهورية وتوقعات التنسيق - موقع شبابيك</title> <meta property="og:title" content=\'نتيجة الثانوية العامة 2022 بالاسم والمدرسة وترتيب الجمهورية - موقع شبابيك\' /> <meta property="og:description" content=\'لأول مره على موقع شبابيك نتيجة الثانوية العامة 2022\' /> <meta charset="UTF-8"> <meta property="og:type" content="article" /> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"> <link rel="preload" href="//fonts.gstatic.com/ea/notonaskharabicui/v1/NotoNaskhArabicUI-Regular.woff2" crossorigin="anonymous" as="font" type="font/woff2"> <link rel="preload" href="https://fonts.gstatic.com/s/notokufiarabic/v8/CSRk4ydQnPyaDxEXLFF6LZVLKrodrOYFFg.woff2" crossorigin="anonymous" as="font" type="font/woff2"> <meta name="google-site-verification" content="yCpKJTILfbonDIdXsgFFZskmEGC_5x_6mpCCYcrHqsY" /> <meta name="theme-color" content="#ffffff"> <link rel="manifest" href="/manifest.json"> <link rel="preload" type="font/woff2" as="font" href="https://fonts.gstatic.com/s/notokufiarabic/v8/CSRk4ydQnPyaDxEXLFF6LZVLKrodrOYFFg.woff2" crossorigin="anonymous"> <link rel="preload" type="font/woff2" as="font" href="//fonts.gstatic.com/ea/notonaskharabicui/v1/NotoNaskhArabicUI-Regular.woff2" crossorigin="anonymous"> <script async src="https://www.googletagmanager.com/gtag/js?id=UA-67885755-1"></script> <script> window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag(\'js\', new Date()); gtag(\'config\', \'UA-67885755-1\'); </script> <script async src="https://www.googletagmanager.com/gtag/js?id=G-98RM5XLQD9"></script> <script> window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag(\'js\', new Date()); gtag(\'config\', \'G-98RM5XLQD9\'); </script> <script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js" crossorigin="anonymous"></script> <ins class="adsbygoogle" style="display:block" data-ad-client="ca-pub-4021893257422147" data-ad-format="auto" data-ad-channel="4776241739" data-full-width-responsive="true"></ins> <script> (adsbygoogle = window.adsbygoogle || []).push({}); </script> <link rel="preload" href="https://shbabbek.com/assets/css/sty_all_min.css" as="style" /> <link rel="stylesheet" href="https://shbabbek.com/assets/css/sty_all_min.css"> <link rel="stylesheet" href="https://cdn.datatables.net/1.12.1/css/jquery.dataTables.min.css"> <style> html{font-family:Greta,BlinkMacSystemFont,"Segoe UI",Roboto,"Helvetica Neue",Noto,sans-serif;font-size:16px;font-weight:400;line-height:1.5;-webkit-text-size-adjust:100%;background:#fff;color:#666}body{margin:0}a{-webkit-text-decoration-skip:objects}a:active,a:hover{outline:0}a{color:#1e87f0;text-decoration:none;cursor:pointer}a:hover{color:#0f6ecd;text-decoration:underline}strong{font-weight:bolder}img{vertical-align:middle}.nav-search-button svg{width:50%;margin:25% 5px 5px}img{max-width:100%;box-sizing:border-box}p,ul{margin:0}*+p,*+ul{margin-top:20px}h1,h2,h3,h4{margin:0 0 10px;font-family:-apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,"Helvetica Neue",Noto,sans-serif;font-weight:400;color:#333;text-transform:none}*+h2{margin-top:0}h1{font-size:2.23125rem;line-height:1.2}h2{font-size:1.7rem;line-height:1.3}h3{font-size:1.5rem;line-height:1.4}h4{font-size:1.25rem;line-height:1.4}@media (min-width:960px){h1{font-size:2.625rem}h2{font-size:2rem}}ul{padding-left:30px}ul>li>ul{margin:0}::-moz-selection{background:#39f;color:#fff;text-shadow:none}::selection{background:#39f;color:#fff;text-shadow:none}a,button,input{touch-action:manipulation}@media print{*,::after,::before{background:0 0!important;color:#000!important;box-shadow:none!important;text-shadow:none!important}a,a:visited{text-decoration:underline}img{page-break-inside:avoid;max-width:100%!important}h2,h3,p{orphans:3;widows:3}h2,h3{page-break-aft ...

# %%
my_list[5].text
# Out:
# '<!DOCTYPE html> <html lang="en"> <head> <title>نتيجة وتنسيق الثانوية العامة الدور الثانى 2022 بالاسم والمدرسة وترتيب الجمهورية وتوقعات التنسيق - موقع شبابيك</title> <meta property="og:title" content=\'نتيجة الثانوية العامة 2022 بالاسم والمدرسة وترتيب الجمهورية - موقع شبابيك\' /> <meta property="og:description" content=\'لأول مره على موقع شبابيك نتيجة الثانوية العامة 2022\' /> <meta charset="UTF-8"> <meta property="og:type" content="article" /> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"> <link rel="preload" href="//fonts.gstatic.com/ea/notonaskharabicui/v1/NotoNaskhArabicUI-Regular.woff2" crossorigin="anonymous" as="font" type="font/woff2"> <link rel="preload" href="https://fonts.gstatic.com/s/notokufiarabic/v8/CSRk4ydQnPyaDxEXLFF6LZVLKrodrOYFFg.woff2" crossorigin="anonymous" as="font" type="font/woff2"> <meta name="google-site-verification" content="yCpKJTILfbonDIdXsgFFZskmEGC_5x_6mpCCYcrHqsY" /> <meta name="theme-color" content="#ffffff"> <link rel="manifest" href="/manifest.json"> <link rel="preload" type="font/woff2" as="font" href="https://fonts.gstatic.com/s/notokufiarabic/v8/CSRk4ydQnPyaDxEXLFF6LZVLKrodrOYFFg.woff2" crossorigin="anonymous"> <link rel="preload" type="font/woff2" as="font" href="//fonts.gstatic.com/ea/notonaskharabicui/v1/NotoNaskhArabicUI-Regular.woff2" crossorigin="anonymous"> <script async src="https://www.googletagmanager.com/gtag/js?id=UA-67885755-1"></script> <script> window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag(\'js\', new Date()); gtag(\'config\', \'UA-67885755-1\'); </script> <script async src="https://www.googletagmanager.com/gtag/js?id=G-98RM5XLQD9"></script> <script> window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag(\'js\', new Date()); gtag(\'config\', \'G-98RM5XLQD9\'); </script> <script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js" crossorigin="anonymous"></script> <ins class="adsbygoogle" style="display:block" data-ad-client="ca-pub-4021893257422147" data-ad-format="auto" data-ad-channel="4776241739" data-full-width-responsive="true"></ins> <script> (adsbygoogle = window.adsbygoogle || []).push({}); </script> <link rel="preload" href="https://shbabbek.com/assets/css/sty_all_min.css" as="style" /> <link rel="stylesheet" href="https://shbabbek.com/assets/css/sty_all_min.css"> <link rel="stylesheet" href="https://cdn.datatables.net/1.12.1/css/jquery.dataTables.min.css"> <style> html{font-family:Greta,BlinkMacSystemFont,"Segoe UI",Roboto,"Helvetica Neue",Noto,sans-serif;font-size:16px;font-weight:400;line-height:1.5;-webkit-text-size-adjust:100%;background:#fff;color:#666}body{margin:0}a{-webkit-text-decoration-skip:objects}a:active,a:hover{outline:0}a{color:#1e87f0;text-decoration:none;cursor:pointer}a:hover{color:#0f6ecd;text-decoration:underline}strong{font-weight:bolder}img{vertical-align:middle}.nav-search-button svg{width:50%;margin:25% 5px 5px}img{max-width:100%;box-sizing:border-box}p,ul{margin:0}*+p,*+ul{margin-top:20px}h1,h2,h3,h4{margin:0 0 10px;font-family:-apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,"Helvetica Neue",Noto,sans-serif;font-weight:400;color:#333;text-transform:none}*+h2{margin-top:0}h1{font-size:2.23125rem;line-height:1.2}h2{font-size:1.7rem;line-height:1.3}h3{font-size:1.5rem;line-height:1.4}h4{font-size:1.25rem;line-height:1.4}@media (min-width:960px){h1{font-size:2.625rem}h2{font-size:2rem}}ul{padding-left:30px}ul>li>ul{margin:0}::-moz-selection{background:#39f;color:#fff;text-shadow:none}::selection{background:#39f;color:#fff;text-shadow:none}a,button,input{touch-action:manipulation}@media print{*,::after,::before{background:0 0!important;color:#000!important;box-shadow:none!important;text-shadow:none!important}a,a:visited{text-decoration:underline}img{page-break-inside:avoid;max-width:100%!important}h2,h3,p{orphans:3;widows:3}h2,h3{page-break-aft ...

# %%
sourse =response.content

# %%
response.text
# Out:
# '<!DOCTYPE html> <html lang="en"> <head> <title>نتيجة وتنسيق الثانوية العامة الدور الثانى 2022 بالاسم والمدرسة وترتيب الجمهورية وتوقعات التنسيق - موقع شبابيك</title> <meta property="og:title" content=\'نتيجة الثانوية العامة 2022 بالاسم والمدرسة وترتيب الجمهورية - موقع شبابيك\' /> <meta property="og:description" content=\'لأول مره على موقع شبابيك نتيجة الثانوية العامة 2022\' /> <meta charset="UTF-8"> <meta property="og:type" content="article" /> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"> <link rel="preload" href="//fonts.gstatic.com/ea/notonaskharabicui/v1/NotoNaskhArabicUI-Regular.woff2" crossorigin="anonymous" as="font" type="font/woff2"> <link rel="preload" href="https://fonts.gstatic.com/s/notokufiarabic/v8/CSRk4ydQnPyaDxEXLFF6LZVLKrodrOYFFg.woff2" crossorigin="anonymous" as="font" type="font/woff2"> <meta name="google-site-verification" content="yCpKJTILfbonDIdXsgFFZskmEGC_5x_6mpCCYcrHqsY" /> <meta name="theme-color" content="#ffffff"> <link rel="manifest" href="/manifest.json"> <link rel="preload" type="font/woff2" as="font" href="https://fonts.gstatic.com/s/notokufiarabic/v8/CSRk4ydQnPyaDxEXLFF6LZVLKrodrOYFFg.woff2" crossorigin="anonymous"> <link rel="preload" type="font/woff2" as="font" href="//fonts.gstatic.com/ea/notonaskharabicui/v1/NotoNaskhArabicUI-Regular.woff2" crossorigin="anonymous"> <script async src="https://www.googletagmanager.com/gtag/js?id=UA-67885755-1"></script> <script> window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag(\'js\', new Date()); gtag(\'config\', \'UA-67885755-1\'); </script> <script async src="https://www.googletagmanager.com/gtag/js?id=G-98RM5XLQD9"></script> <script> window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag(\'js\', new Date()); gtag(\'config\', \'G-98RM5XLQD9\'); </script> <script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js" crossorigin="anonymous"></script> <ins class="adsbygoogle" style="display:block" data-ad-client="ca-pub-4021893257422147" data-ad-format="auto" data-ad-channel="4776241739" data-full-width-responsive="true"></ins> <script> (adsbygoogle = window.adsbygoogle || []).push({}); </script> <link rel="preload" href="https://shbabbek.com/assets/css/sty_all_min.css" as="style" /> <link rel="stylesheet" href="https://shbabbek.com/assets/css/sty_all_min.css"> <link rel="stylesheet" href="https://cdn.datatables.net/1.12.1/css/jquery.dataTables.min.css"> <style> html{font-family:Greta,BlinkMacSystemFont,"Segoe UI",Roboto,"Helvetica Neue",Noto,sans-serif;font-size:16px;font-weight:400;line-height:1.5;-webkit-text-size-adjust:100%;background:#fff;color:#666}body{margin:0}a{-webkit-text-decoration-skip:objects}a:active,a:hover{outline:0}a{color:#1e87f0;text-decoration:none;cursor:pointer}a:hover{color:#0f6ecd;text-decoration:underline}strong{font-weight:bolder}img{vertical-align:middle}.nav-search-button svg{width:50%;margin:25% 5px 5px}img{max-width:100%;box-sizing:border-box}p,ul{margin:0}*+p,*+ul{margin-top:20px}h1,h2,h3,h4{margin:0 0 10px;font-family:-apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,"Helvetica Neue",Noto,sans-serif;font-weight:400;color:#333;text-transform:none}*+h2{margin-top:0}h1{font-size:2.23125rem;line-height:1.2}h2{font-size:1.7rem;line-height:1.3}h3{font-size:1.5rem;line-height:1.4}h4{font-size:1.25rem;line-height:1.4}@media (min-width:960px){h1{font-size:2.625rem}h2{font-size:2rem}}ul{padding-left:30px}ul>li>ul{margin:0}::-moz-selection{background:#39f;color:#fff;text-shadow:none}::selection{background:#39f;color:#fff;text-shadow:none}a,button,input{touch-action:manipulation}@media print{*,::after,::before{background:0 0!important;color:#000!important;box-shadow:none!important;text-shadow:none!important}a,a:visited{text-decoration:underline}img{page-break-inside:avoid;max-width:100%!important}h2,h3,p{orphans:3;widows:3}h2,h3{page-break-aft ...

# %%
soup=BeautifulSoup(sourse,"lxml")

# %%
seat_no=soup.find_all("td")[21].get_text()

# %%
print(seat_no)
# Out:
# 900009

# %%
name=soup.find_all("td")[23].get_text()

# %%
print(name)
# Out:
# محمد حمدان شاكر عثمان

# %%
sc_name=soup.find_all("td")[25].get_text()

# %%
print(sc_name)
# Out:
# فصول خدمات صدفا الثانوية بنين

# %%
edu_adminstration=soup.find_all("td")[27].get_text()

# %%
print(edu_adminstration)
# Out:
# صدفا

# %%
select_division=soup.find_all("td")[29].get_text()

# %%
print(select_division)
# Out:
# علمي علوم

# %%
total_marks=soup.find_all("td")[31].get_text()

# %%
print(total_marks)
# Out:
# 148

# %%
percentage=soup.find_all("td")[33].get_text()

# %%
print(percentage)
# Out:
# 36.1%

# %%
passed=soup.find_all("td")[37].get_text()

# %%
print(passed)
# Out:
# راسب

# %%
arabic=soup.find_all("td")[39].get_text()
print(arabic)
# Out:
# 40

# %%
english=soup.find_all("td")[41].get_text()
print(english)
# Out:
# 10

# %%
third_lang=soup.find_all("td")[43].get_text()
print(third_lang)
# Out:
# 20

# %% [markdown]
# Apply code on a large Scope of data

# %%
def extraction(response):
    soup = BeautifulSoup(response, 'lxml')
    result = {}
    result["seat_no"]=(soup.find_all("td")[21].get_text().strip())
    result["name"]=soup.find_all("td")[23].get_text().strip()
    result["total_marks"]=(soup.find_all("td")[31].get_text().strip())
    result["percentage"]=(soup.find_all("td")[33].get_text().strip())
    result["sc_name"]=soup.find_all("td")[25].get_text().strip()
    result["edu_administration"]=soup.find_all("td")[27].get_text().strip()
    #check pass or fill
    result["passed"]=1 if(soup.find_all("td")[37].get_text().split()[0]=="ناجح") else[0]
    #select division
    result["select_division"]=soup.find_all("td")[29].get_text().strip()
    #get the result of the fixed subjects
    result["arabic"]=(soup.find_all("td")[39].get_text().strip())
    result["english"]=(soup.find_all("td")[41].get_text().strip())
    result["third_lang"]=(soup.find_all("td")[43].get_text().strip())
    #extracte each division
    if result["select_division"][0]=="أدبى":
      result["history"]=(soup.find_all("td")[47].get_text().strip())
      result["geograpgy"]=(soup.find_all("td")[49].get_text().strip())
      result["philosophy"]=(soup.find_all("td")[51].get_text().strip())
      result["psychology"]=(soup.find_all("td")[53].get_text().strip())
    elif result["select_division"][0]=="علمى علوم":
        result["chemistry"]=(soup.find_all("td")[55].get_text().strip())
        result["biology"]=(soup.find_all("td")[57].get_text().strip())
        result["geology"]=(soup.find_all("td")[61].get_text().strip())
        result["physics"]=(soup.find_all("td")[65].get_text().strip())
    elif result["select_division"][0]=="علمى رياضة":
      result["chemistry"]=(soup.find_all("td")[55].get_text().strip())
      result["physics"]=(soup.find_all("td")[65].get_text().strip())
      result["pure_math"]=(soup.find_all("td")[45].get_text().strip())
      result["applied_math"]=(soup.find_all("td")[63].get_text().strip())
    #abstract addition subjects
    try:
      result["relegion"]=(soup.find_all("td")[69].get_text().strip())
      result["nat_edu"]=(soup.find_all("td")[71].get_text().strip())
      result["stat_eco"]=(soup.find_all("td")[73].get_text().strip())
    except:
      result['religion'] = pd.NA
      result['nat_edu'] = pd.NA 
      result['stat_eco'] = pd.NA 
    return result

# %%
soup = BeautifulSoup(my_list[0].content, 'lxml')

soup.find_all("td")[21].get_text()
# Out:
# 'المدرسة'

# %%
extraction(my_list[3].content)
# Out:
# {'seat_no': '900003',
#  'name': 'نصر جمال نصر حسن',
#  'total_marks': '150',
#  'percentage': '36.59%',
#  'sc_name': 'فصول خدمات صدفا الثانوية بنين',
#  'edu_administration': 'صدفا',
#  'passed': [0],
#  'select_division': 'أدبي',
#  'arabic': '20',
#  'english': '13',
#  'third_lang': '11',
#  'relegion': '20',
#  'nat_edu': <NA>,
#  'religion': <NA>,
#  'stat_eco': <NA>}

# %%
final = pd.DataFrame()
for i in my_list[1:]:
  sourse =i.content
  result = extraction(sourse)
  final = final.append(result,ignore_index=True)

# %%
final
# Out:
#    seat_no                           name total_marks   percentage  \
# 0   900001         مصطفى جمال مخيمر فرغلى         207       50.49%
# 1  المدرسة                        الإدارة  نوع الطالب  حالة الطالب
# 2   900003               نصر جمال نصر حسن         150       36.59%
# 3   900004            احمد ثابت محمد ثابت         163       39.76%
# 4   900005             احمد محمد على محمد         135       32.93%
# 5   900006  عبد الحميد عماد عبدالحميد زكى         165       40.24%
# 6   900007             كامل جاد كامل عارف         127       30.98%
# 7   900008     كريم عاطف عبد الحميد خليفه          98        23.9%
# 8   900009          محمد حمدان شاكر عثمان         148        36.1%
#
#                          sc_name edu_administration passed select_division  \
# 0  فصول خدمات صدفا الثانوية بنين               صدفا    [0]            أدبي
# 1                         الشعبة            المجموع    [0]  النسبة المئوية
# 2  فصول خدمات صدفا الثانوية بنين               صدفا    [0]            أدبي
# 3  فصول خدمات صدفا الثانوية بنين               صدفا    [0]       علمي علوم
# 4  فصول خدمات صدفا الثانوية بنين               صدفا    [0]       علمي علوم
# 5  فصول خدمات صدفا الثانوية بنين               صدفا    [0]       علمي علوم
# 6  فصول خدمات صدفا الثانوية بنين               صدفا    [0]       علمي علوم
# 7  فصول خدمات صدفا الثانوية بنين               صدفا    [0]       علمي علوم
# 8  فصول خدمات صدفا الثانوية بنين               صدفا    [0]       علمي علوم
#
#                    arabic                 english third_lang relegion nat_edu  \
# 0                      44                      12         32       14     NaN
# 1  اللغة الأجنبية الثانية  مجموع الرياضيات البحتة    التاريخ      NaN     NaN
# 2                      20                      13         11       20     NaN
# 3                      40                      19         20       18     NaN
# 4                      40                      17         14       18     NaN
# 5                      40                      16         27       16     NaN
# 6                      26                      18         21       18     NaN
# 7                      20                      10          8       18     NaN
# 8                      40                      10         20       14     NaN
#
#   religion stat_eco
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN
# 5      NaN      NaN
# 6      NaN      NaN
# 7      NaN      NaN
# 8      NaN      NaN

# %%
final.to_csv('frist_Exam_Result.csv',index=False)

# %%
for x in range(900000,900010):
  print(result)
# Out:
# {'seat_no': '900009', 'name': 'محمد حمدان شاكر عثمان', 'total_marks': '148', 'percentage': '36.1%', 'sc_name': 'فصول خدمات صدفا الثانوية بنين', 'edu_administration': 'صدفا', 'passed': [0], 'select_division': 'علمي علوم', 'arabic': '40', 'english': '10', 'third_lang': '20', 'relegion': '14', 'nat_edu': <NA>, 'religion': <NA>, 'stat_eco': <NA>}
# {'seat_no': '900009', 'name': 'محمد حمدان شاكر عثمان', 'total_marks': '148', 'percentage': '36.1%', 'sc_name': 'فصول خدمات صدفا الثانوية بنين', 'edu_administration': 'صدفا', 'passed': [0], 'select_division': 'علمي علوم', 'arabic': '40', 'english': '10', 'third_lang': '20', 'relegion': '14', 'nat_edu': <NA>, 'religion': <NA>, 'stat_eco': <NA>}
# {'seat_no': '900009', 'name': 'محمد حمدان شاكر عثمان', 'total_marks': '148', 'percentage': '36.1%', 'sc_name': 'فصول خدمات صدفا الثانوية بنين', 'edu_administration': 'صدفا', 'passed': [0], 'select_division': 'علمي علوم', 'arabic': '40', 'english': '10', 'third_lang': '20', 'relegion': '14', 'nat_edu': <NA>, 'religion': <NA>, 'stat_eco': <NA>}
# {'seat_no': '900009', 'name': 'محمد حمدان شاكر عثمان', 'total_marks': '148', 'percentage': '36.1%', 'sc_name': 'فصول خدمات صدفا الثانوية بنين', 'edu_administration': 'صدفا', 'passed': [0], 'select_division': 'علمي علوم', 'arabic': '40', 'english': '10', 'third_lang': '20', 'relegion': '14', 'nat_edu': <NA>, 'religion': <NA>, 'stat_eco': <NA>}
# {'seat_no': '900009', 'name': 'محمد حمدان شاكر عثمان', 'total_marks': '148', 'percentage': '36.1%', 'sc_name': 'فصول خدمات صدفا الثانوية بنين', 'edu_administration': 'صدفا', 'passed': [0], 'select_division': 'علمي علوم', 'arabic': '40', 'english': '10', 'third_lang': '20', 'relegion': '14', 'nat_edu': <NA>, 'religion': <NA>, 'stat_eco': <NA>}
# {'seat_no': '900009', 'name': 'محمد حمدان شاكر عثمان', 'total_marks': '148', 'percentage': '36.1%', 'sc_name': 'فصول خدمات صدفا الثانوية بنين', 'edu_administration': 'صدفا', 'passed': [0], 'select_division': 'علمي علوم', 'arabic': '40', 'english': '10', 'third_lang': '20', 'relegion': '14', 'nat_edu': <NA>, 'religion': <NA>, 'stat_eco': <NA>}
# {'seat_no': '900009', 'name': 'محمد حمدان شاكر عثمان', 'total_marks': '148', 'percentage': '36.1%', 'sc_name': 'فصول خدمات صدفا الثانوية بنين', 'edu_administration': 'صدفا', 'passed': [0], 'select_division': 'علمي علوم', 'arabic': '40', 'english': '10', 'third_lang': '20', 'relegion': '14', 'nat_edu': <NA>, 'religion': <NA>, 'stat_eco': <NA>}
# {'seat_no': '900009', 'name': 'محمد حمدان شاكر عثمان', 'total_marks': '148', 'percentage': '36.1%', 'sc_name': 'فصول خدمات صدفا الثانوية بنين', 'edu_administration': 'صدفا', 'passed': [0], 'select_division': 'علمي علوم', 'arabic': '40', 'english': '10', 'third_lang': '20', 'relegion': '14', 'nat_edu': <NA>, 'religion': <NA>, 'stat_eco': <NA>}
# {'seat_no': '900009', 'name': 'محمد حمدان شاكر عثمان', 'total_marks': '148', 'percentage': '36.1%', 'sc_name': 'فصول خدمات صدفا الثانوية بنين', 'edu_administration': 'صدفا', 'passed': [0], 'select_division': 'علمي علوم', 'arabic': '40', 'english': '10', 'third_lang': '20', 'relegion': '14', 'nat_edu': <NA>, 'religion': <NA>, 'stat_eco': <NA>}
# {'seat_no': '900009', 'name': 'محمد حمدان شاكر عثمان', 'total_marks': '148', 'percentage': '36.1%', 'sc_name': 'فصول خدمات صدفا الثانوية بنين', 'edu_administration': 'صدفا', 'passed': [0], 'select_division': 'علمي علوم', 'arabic': '40', 'english': '10', 'third_lang': '20', 'relegion': '14', 'nat_edu': <NA>, 'religion': <NA>, 'stat_eco': <NA>}

# %%
for x in range(len(range(900000,900010))):
  print(extraction(my_list[x].content))
# Out:
# {'seat_no': 'المدرسة', 'name': 'الإدارة', 'total_marks': 'نوع الطالب', 'percentage': 'حالة الطالب', 'sc_name': 'الشعبة', 'edu_administration': 'المجموع', 'passed': [0], 'select_division': 'النسبة المئوية', 'arabic': 'اللغة الأجنبية الثانية', 'english': 'مجموع الرياضيات البحتة', 'third_lang': 'التاريخ', 'religion': <NA>, 'nat_edu': <NA>, 'stat_eco': <NA>}
# {'seat_no': '900001', 'name': 'مصطفى جمال مخيمر فرغلى', 'total_marks': '207', 'percentage': '50.49%', 'sc_name': 'فصول خدمات صدفا الثانوية بنين', 'edu_administration': 'صدفا', 'passed': [0], 'select_division': 'أدبي', 'arabic': '44', 'english': '12', 'third_lang': '32', 'relegion': '14', 'nat_edu': <NA>, 'religion': <NA>, 'stat_eco': <NA>}
# {'seat_no': 'المدرسة', 'name': 'الإدارة', 'total_marks': 'نوع الطالب', 'percentage': 'حالة الطالب', 'sc_name': 'الشعبة', 'edu_administration': 'المجموع', 'passed': [0], 'select_division': 'النسبة المئوية', 'arabic': 'اللغة الأجنبية الثانية', 'english': 'مجموع الرياضيات البحتة', 'third_lang': 'التاريخ', 'religion': <NA>, 'nat_edu': <NA>, 'stat_eco': <NA>}
# {'seat_no': '900003', 'name': 'نصر جمال نصر حسن', 'total_marks': '150', 'percentage': '36.59%', 'sc_name': 'فصول خدمات صدفا الثانوية بنين', 'edu_administration': 'صدفا', 'passed': [0], 'select_division': 'أدبي', 'arabic': '20', 'english': '13', 'third_lang': '11', 'relegion': '20', 'nat_edu': <NA>, 'religion': <NA>, 'stat_eco': <NA>}
# {'seat_no': '900004', 'name': 'احمد ثابت محمد ثابت', 'total_marks': '163', 'percentage': '39.76%', 'sc_name': 'فصول خدمات صدفا الثانوية بنين', 'edu_administration': 'صدفا', 'passed': [0], 'select_division': 'علمي علوم', 'arabic': '40', 'english': '19', 'third_lang': '20', 'relegion': '18', 'nat_edu': <NA>, 'religion': <NA>, 'stat_eco': <NA>}
# {'seat_no': '900005', 'name': 'احمد محمد على محمد', 'total_marks': '135', 'percentage': '32.93%', 'sc_name': 'فصول خدمات صدفا الثانوية بنين', 'edu_administration': 'صدفا', 'passed': [0], 'select_division': 'علمي علوم', 'arabic': '40', 'english': '17', 'third_lang': '14', 'relegion': '18', 'nat_edu': <NA>, 'religion': <NA>, 'stat_eco': <NA>}
# {'seat_no': '900006', 'name': 'عبد الحميد عماد عبدالحميد زكى', 'total_marks': '165', 'percentage': '40.24%', 'sc_name': 'فصول خدمات صدفا الثانوية بنين', 'edu_administration': 'صدفا', 'passed': [0], 'select_division': 'علمي علوم', 'arabic': '40', 'english': '16', 'third_lang': '27', 'relegion': '16', 'nat_edu': <NA>, 'religion': <NA>, 'stat_eco': <NA>}
# {'seat_no': '900007', 'name': 'كامل جاد كامل عارف', 'total_marks': '127', 'percentage': '30.98%', 'sc_name': 'فصول خدمات صدفا الثانوية بنين', 'edu_administration': 'صدفا', 'passed': [0], 'select_division': 'علمي علوم', 'arabic': '26', 'english': '18', 'third_lang': '21', 'relegion': '18', 'nat_edu': <NA>, 'religion': <NA>, 'stat_eco': <NA>}
# {'seat_no': '900008', 'name': 'كريم عاطف عبد الحميد خليفه', 'total_marks': '98', 'percentage': '23.9%', 'sc_name': 'فصول خدمات صدفا الثانوية بنين', 'edu_administration': 'صدفا', 'passed': [0], 'select_division': 'علمي علوم', 'arabic': '20', 'english': '10', 'third_lang': '8', 'relegion': '18', 'nat_edu': <NA>, 'religion': <NA>, 'stat_eco': <NA>}
# {'seat_no': '900009', 'name': 'محمد حمدان شاكر عثمان', 'total_marks': '148', 'percentage': '36.1%', 'sc_name': 'فصول خدمات صدفا الثانوية بنين', 'edu_administration': 'صدفا', 'passed': [0], 'select_division': 'علمي علوم', 'arabic': '40', 'english': '10', 'third_lang': '20', 'relegion': '14', 'nat_edu': <NA>, 'religion': <NA>, 'stat_eco': <NA>}

# %% [markdown]
# See the time  that Respone taken

# %%
print("the average time per call of Synchronous Approach (Sequential): ")
# %timeit response(900009)

# responce is class that i thenk  must access function inside it like  not take argumant like response(900009)
# %timeit response.json
# Out:
# the average time per call of Synchronous Approach (Sequential):
# 67.6 ns ± 1.78 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
final.to_csv('frist_Exam_Result.csv',index=False)
